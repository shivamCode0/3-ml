# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "tmp/spa.txt"

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 69
# Number of unique output tokens: 84
# Max sequence length for inputs: 16
# Max sequence length for outputs: 47

# %%
import json
json.dump(list(zip(input_texts, target_texts)), open('data.json', 'w'))

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, None, 69)]   0           []
#
#  input_6 (InputLayer)           [(None, None, 84)]   0           []
#
#  lstm_2 (LSTM)                  [(None, 256),        333824      ['input_5[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_3 (LSTM)                  [(None, None, 256),  349184      ['input_6[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]']
#
#  dense_1 (Dense)                (None, None, 84)     21588       ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 704,596
# Trainable params: 704,596
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("tmp/s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 5s 22ms/step - loss: 1.2676 - accuracy: 0.6997 - val_loss: 1.1892 - val_accuracy: 0.6781
# Epoch 2/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.9269 - accuracy: 0.7474 - val_loss: 0.9550 - val_accuracy: 0.7295
# Epoch 3/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.7671 - accuracy: 0.7803 - val_loss: 0.8372 - val_accuracy: 0.7520
# Epoch 4/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.6804 - accuracy: 0.7971 - val_loss: 0.7644 - val_accuracy: 0.7709
# Epoch 5/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.6291 - accuracy: 0.8108 - val_loss: 0.7392 - val_accuracy: 0.7770
# Epoch 6/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5914 - accuracy: 0.8219 - val_loss: 0.6920 - val_accuracy: 0.7905
# Epoch 7/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.5590 - accuracy: 0.8314 - val_loss: 0.6631 - val_accuracy: 0.7995
# Epoch 8/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5313 - accuracy: 0.8397 - val_loss: 0.6361 - val_accuracy: 0.8087
# Epoch 9/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5061 - accuracy: 0.8478 - val_loss: 0.6192 - val_accuracy: 0.8144
# Epoch 10/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4844 - accuracy: 0.8543 - val_loss: 0.6028 - val_accuracy: 0.8200
# Epoch 11/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4636 - accuracy: 0.8609 - val_loss: 0.5931 - val_accuracy: 0.8226
# Epoch 12/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4453 - accuracy: 0.8662 - val_loss: 0.5816 - val_accuracy: 0.8274
# Epoch 13/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.4279 - accuracy: 0.8712 - val_loss: 0.5752 - val_accuracy: 0.8289
# Epoch 14/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.4120 - accuracy: 0.8763 - val_loss: 0.5674 - val_accuracy: 0.8317
# Epoch 15/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3967 - accuracy: 0.8807 - val_loss: 0.5577 - val_accuracy: 0.8350
# Epoch 16/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3816 - accuracy: 0.8854 - val_loss: 0.5617 - val_accuracy: 0.8350
# Epoch 17/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3679 - accuracy: 0.8897 - val_loss: 0.5538 - val_accuracy: 0.8382
# Epoch 18/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3546 - accuracy: 0.8936 - val_loss: 0.5557 - val_accuracy: 0.8379
# Epoch 19/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3419 - accuracy: 0.8978 - val_loss: 0.5506 - val_accuracy: 0.8412
# Epoch 20/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3298 - accuracy: 0.9015 - val_loss: 0.5554 - val_accuracy: 0.8398
# Epoch 21/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3177 - accuracy: 0.9047 - val_loss: 0.5522 - val_accuracy: 0.8421
# Epoch 22/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3063 - accuracy: 0.9080 - val_loss: 0.5538 - val_accuracy: 0.8420
# Epoch 23/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2953 - accuracy: 0.9115 - val_loss: 0.5563 - val_accuracy: 0.8414
# Epoch 24/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2846 - accuracy: 0.9145 - val_loss: 0.5589 - val_accuracy: 0.8413
# Epoch 25/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2745 - accuracy: 0.9174 - val_loss: 0.5678 - val_accuracy: 0.8419
# Epoch 26/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2646 - accuracy: 0.9204 - val_loss: 0.5662 - val_accuracy: 0.8415
# Epoch 27/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2549 - accuracy: 0.9234 - val_loss: 0.5698 - val_accuracy: 0.8430
# Epoch 28/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2462 - accuracy: 0.9256 - val_loss: 0.5744 - val_accuracy: 0.8424
# Epoch 29/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2371 - accuracy: 0.9286 - val_loss: 0.5788 - val_accuracy: 0.8421
# Epoch 30/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2283 - accuracy: 0.9309 - val_loss: 0.5879 - val_accuracy: 0.8421
# Epoch 31/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2198 - accuracy: 0.9339 - val_loss: 0.5901 - val_accuracy: 0.8433
# Epoch 32/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2123 - accuracy: 0.9360 - val_loss: 0.5967 - val_accuracy: 0.8410
# Epoch 33/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2043 - accuracy: 0.9386 - val_loss: 0.6096 - val_accuracy: 0.8424
# Epoch 34/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1973 - accuracy: 0.9404 - val_loss: 0.6124 - val_accuracy: 0.8418
# Epoch 35/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1900 - accuracy: 0.9429 - val_loss: 0.6189 - val_accuracy: 0.8413
# Epoch 36/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1834 - accuracy: 0.9448 - val_loss: 0.6299 - val_accuracy: 0.8414
# Epoch 37/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1768 - accuracy: 0.9469 - val_loss: 0.6380 - val_accuracy: 0.8396
# Epoch 38/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1702 - accuracy: 0.9486 - val_loss: 0.6491 - val_accuracy: 0.8395
# Epoch 39/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1641 - accuracy: 0.9506 - val_loss: 0.6501 - val_accuracy: 0.8403
# Epoch 40/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1582 - accuracy: 0.9524 - val_loss: 0.6608 - val_accuracy: 0.8400
# Epoch 41/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1526 - accuracy: 0.9539 - val_loss: 0.6725 - val_accuracy: 0.8401
# Epoch 42/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1478 - accuracy: 0.9554 - val_loss: 0.6822 - val_accuracy: 0.8400
# Epoch 43/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1423 - accuracy: 0.9574 - val_loss: 0.6894 - val_accuracy: 0.8381
# Epoch 44/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1373 - accuracy: 0.9584 - val_loss: 0.6993 - val_accuracy: 0.8389
# Epoch 45/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1325 - accuracy: 0.9601 - val_loss: 0.7074 - val_accuracy: 0.8379
# Epoch 46/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1278 - accuracy: 0.9615 - val_loss: 0.7152 - val_accuracy: 0.8390
# Epoch 47/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1234 - accuracy: 0.9628 - val_loss: 0.7215 - val_accuracy: 0.8386
# Epoch 48/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1193 - accuracy: 0.9641 - val_loss: 0.7330 - val_accuracy: 0.8382
# Epoch 49/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1153 - accuracy: 0.9654 - val_loss: 0.7370 - val_accuracy: 0.8388
# Epoch 50/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1117 - accuracy: 0.9664 - val_loss: 0.7514 - val_accuracy: 0.8369
# Epoch 51/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1075 - accuracy: 0.9676 - val_loss: 0.7557 - val_accuracy: 0.8391
# Epoch 52/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1044 - accuracy: 0.9683 - val_loss: 0.7720 - val_accuracy: 0.8373
# Epoch 53/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1014 - accuracy: 0.9695 - val_loss: 0.7729 - val_accuracy: 0.8373
# Epoch 54/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0981 - accuracy: 0.9704 - val_loss: 0.7785 - val_accuracy: 0.8383
# Epoch 55/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0948 - accuracy: 0.9711 - val_loss: 0.7845 - val_accuracy: 0.8373
# Epoch 56/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0921 - accuracy: 0.9722 - val_loss: 0.8005 - val_accuracy: 0.8361
# Epoch 57/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0893 - accuracy: 0.9731 - val_loss: 0.8143 - val_accuracy: 0.8366
# Epoch 58/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0870 - accuracy: 0.9739 - val_loss: 0.8162 - val_accuracy: 0.8378
# Epoch 59/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0843 - accuracy: 0.9747 - val_loss: 0.8244 - val_accuracy: 0.8355
# Epoch 60/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0821 - accuracy: 0.9752 - val_loss: 0.8315 - val_accuracy: 0.8366
# Epoch 61/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0797 - accuracy: 0.9760 - val_loss: 0.8420 - val_accuracy: 0.8365
# Epoch 62/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0776 - accuracy: 0.9765 - val_loss: 0.8463 - val_accuracy: 0.8363
# Epoch 63/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0755 - accuracy: 0.9771 - val_loss: 0.8545 - val_accuracy: 0.8366
# Epoch 64/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0730 - accuracy: 0.9778 - val_loss: 0.8657 - val_accuracy: 0.8356
# Epoch 65/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0720 - accuracy: 0.9783 - val_loss: 0.8769 - val_accuracy: 0.8353
# Epoch 66/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0700 - accuracy: 0.9787 - val_loss: 0.8830 - val_accuracy: 0.8349
# Epoch 67/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0687 - accuracy: 0.9791 - val_loss: 0.8818 - val_accuracy: 0.8366
# Epoch 68/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0668 - accuracy: 0.9796 - val_loss: 0.8873 - val_accuracy: 0.8358
# Epoch 69/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0650 - accuracy: 0.9802 - val_loss: 0.9014 - val_accuracy: 0.8343
# Epoch 70/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0638 - accuracy: 0.9805 - val_loss: 0.9015 - val_accuracy: 0.8346
# Epoch 71/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0626 - accuracy: 0.9808 - val_loss: 0.9131 - val_accuracy: 0.8335
# Epoch 72/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0609 - accuracy: 0.9813 - val_loss: 0.9132 - val_accuracy: 0.8360
# Epoch 73/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0591 - accuracy: 0.9820 - val_loss: 0.9222 - val_accuracy: 0.8352
# Epoch 74/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0585 - accuracy: 0.9820 - val_loss: 0.9280 - val_accuracy: 0.8349
# Epoch 75/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0574 - accuracy: 0.9822 - val_loss: 0.9394 - val_accuracy: 0.8350
# Epoch 76/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0558 - accuracy: 0.9828 - val_loss: 0.9318 - val_accuracy: 0.8364
# Epoch 77/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0550 - accuracy: 0.9830 - val_loss: 0.9428 - val_accuracy: 0.8350
# Epoch 78/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0541 - accuracy: 0.9833 - val_loss: 0.9425 - val_accuracy: 0.8367
# Epoch 79/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0526 - accuracy: 0.9837 - val_loss: 0.9563 - val_accuracy: 0.8339
# Epoch 80/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0518 - accuracy: 0.9841 - val_loss: 0.9552 - val_accuracy: 0.8347
# Epoch 81/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0510 - accuracy: 0.9843 - val_loss: 0.9615 - val_accuracy: 0.8339
# Epoch 82/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0506 - accuracy: 0.9843 - val_loss: 0.9700 - val_accuracy: 0.8349
# Epoch 83/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0491 - accuracy: 0.9849 - val_loss: 0.9741 - val_accuracy: 0.8344
# Epoch 84/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0487 - accuracy: 0.9846 - val_loss: 0.9841 - val_accuracy: 0.8348
# Epoch 85/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0480 - accuracy: 0.9851 - val_loss: 0.9763 - val_accuracy: 0.8354
# Epoch 86/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0472 - accuracy: 0.9852 - val_loss: 0.9901 - val_accuracy: 0.8352
# Epoch 87/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0466 - accuracy: 0.9854 - val_loss: 0.9904 - val_accuracy: 0.8343
# Epoch 88/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0457 - accuracy: 0.9857 - val_loss: 1.0018 - val_accuracy: 0.8344
# Epoch 89/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0451 - accuracy: 0.9858 - val_loss: 0.9993 - val_accuracy: 0.8348
# Epoch 90/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0446 - accuracy: 0.9859 - val_loss: 1.0043 - val_accuracy: 0.8348
# Epoch 91/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0440 - accuracy: 0.9861 - val_loss: 1.0091 - val_accuracy: 0.8343
# Epoch 92/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0433 - accuracy: 0.9864 - val_loss: 1.0067 - val_accuracy: 0.8346
# Epoch 93/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0427 - accuracy: 0.9863 - val_loss: 1.0189 - val_accuracy: 0.8345
# Epoch 94/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0426 - accuracy: 0.9864 - val_loss: 1.0142 - val_accuracy: 0.8342
# Epoch 95/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0419 - accuracy: 0.9867 - val_loss: 1.0217 - val_accuracy: 0.8334
# Epoch 96/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0414 - accuracy: 0.9867 - val_loss: 1.0239 - val_accuracy: 0.8339
# Epoch 97/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0411 - accuracy: 0.9867 - val_loss: 1.0261 - val_accuracy: 0.8346
# Epoch 98/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0405 - accuracy: 0.9870 - val_loss: 1.0341 - val_accuracy: 0.8352
# Epoch 99/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0401 - accuracy: 0.9871 - val_loss: 1.0365 - val_accuracy: 0.8337
# Epoch 100/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0396 - accuracy: 0.9874 - val_loss: 1.0396 - val_accuracy: 0.8344
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: tmp/s2s\assets
# INFO:tensorflow:Assets written to: tmp/s2s\assets

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("tmp/s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Go.
# Decoded sentence: Vete.
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: Go.
# Decoded sentence: Vete.
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Go.
# Decoded sentence: Vete.
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Go.
# Decoded sentence: Vete.
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Hola.
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Run!
# Decoded sentence: ¡Corred!
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run!
# Decoded sentence: ¡Corred!
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run!
# Decoded sentence: ¡Corred!
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run!
# Decoded sentence: ¡Corred!
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run!
# Decoded sentence: ¡Corred!
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# -
# Input sentence: Run.
# Decoded sentence: Corra.
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Run.
# Decoded sentence: Corra.
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Who?
# Decoded sentence: ¿Quién?
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Wow!
# Decoded sentence: ¡Órale!
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Duck!
# Decoded sentence: ¡Inclínate!
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Fire!
# Decoded sentence: ¡Disparad!
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Fire!
# Decoded sentence: ¡Disparad!
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Fire!
# Decoded sentence: ¡Disparad!
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Help!
# Decoded sentence: ¡Ayuda!
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Help!
# Decoded sentence: ¡Ayuda!
